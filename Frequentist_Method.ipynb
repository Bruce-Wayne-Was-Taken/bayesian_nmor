# %%
from core import altopt, plot_altopt
from core import DataContext, ParameterContext
from core import get_final_interpolator, load_experiment, get_predictions_batch
import os
from scipy.optimize import curve_fit
import numpy as np
import pandas as pd
import cupy as cp
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.ticker as ticker
plt.rcParams.update({'font.family': 'serif', 
                     'font.serif' : 'Times New Roman',
                     'mathtext.fontset' : 'stix',
                     'mathtext.default' : 'it',
                     'font.size': 15})

# %%
def pad_and_save(data, filename):
    max_len = max(len(arr) for arr in data)
    padded_matrix = np.full((len(data), max_len),np.nan)
    for i, arr in enumerate(data):
        padded_matrix[i, :len(arr)] = arr
    np.savetxt(filename, padded_matrix, delimiter = ",")

# %%
DATA_DIR = r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_10"

ilist = [2]#,1, 2,3]
for i in ilist:
    for j in range(0,2,2):
        # if i in [0,1]: #and j < 8:
        #    continue
        curr_time = 35.0 + j
        DATASET3 = DataContext(
            sim_time = os.path.join(DATA_DIR, "t_array.csv"),
            sim_freq = os.path.join(DATA_DIR, "delz_MHz.csv"),
        sim_by = os.path.join(DATA_DIR, "dely_MHz.csv"),
        sim_intensities = sorted([
            os.path.join(DATA_DIR, f) for f in os.listdir(DATA_DIR) if f.startswith("transH_t_vs_Bz_alpha2500_delx_0_dely_") and f.endswith(".csv")
        ], key=lambda x: float(x.split("_dely_")[1].split(".csv")[0])),
        exp_time = r"DataFiles_to_Dinesh_Pranav\Data_files\Experiment\26_03_2026_CW_data\t_array_ Copy.csv",
        exp_freq_axis = r"DataFiles_to_Dinesh_Pranav\Data_files\Experiment\26_03_2026_CW_data\Bz_Y_MHz.csv",
        exp_data = f"DataFiles_to_Dinesh_Pranav\\Data_files\\Experiment\\26_03_2026_CW_data\\Bz_V_Readout_By_{i}.csv",
        save_path = f"Results\\Dataset_10\\05_June\\Frequentist\\Linear_Interpolation\\Test_{(j//2)}_Dataset_10_By_{i}_frequentist",
        interpolator=r"DataFiles_to_Dinesh_Pranav\Data_files\Simulation\Dataset_10\gpu_sim_interpolator_new_normalisation_linear_spline_0.3_threshold.npz",
        Sim_Aligned = True,
        Exp_Aligned = False,
        sim_pulse_thresh=0.3, 
        exp_pulse_thresh=0.3
        )
        DEFAULT_ALTOPT_PARAMS = ParameterContext(
            num_iter=10,
            curr_time = curr_time,
            max_time = 70.0,
            tol_bz=1e-20,
            tol_by=1e-20,
            t_step = 0.2,
            fixed_by_estimate=0.0,
            B_unk_bound_transverse_upper=0.4,
            fixed_bz_estimate=0.0,
            print_plot = False,
            Est_First_Z= False,
            likelihood_mode_longitudinal="Cauchy",
            likelihood_mode_transverse="Cauchy"
            )
        sign = "plus" if DEFAULT_ALTOPT_PARAMS.fixed_bz_estimate >= 0 else "minus"
        Test = r"Dataset_10_Starting with" + str(DEFAULT_ALTOPT_PARAMS.curr_time) + r" us_T Step " + str(DEFAULT_ALTOPT_PARAMS.t_step) + r" us_" + sign + r"_" + str(np.abs(DEFAULT_ALTOPT_PARAMS.fixed_bz_estimate)) + r"_initial estimate"
        save_path = sign + r"_" + str(np.abs(DEFAULT_ALTOPT_PARAMS.fixed_bz_estimate)) + r"_initial_estimate"
        DEFAULT_ALTOPT_PARAMS.Test = Test

# %% [markdown]
# Frequentist Benchmark

# %% [markdown]
# Firstly, we load the simulator and the file

# %%
t_sim, f_sim, by_sim, sim_spline = get_final_interpolator(DATASET3, DEFAULT_ALTOPT_PARAMS)
t_exp, f_bias_axis, exp_matrix = load_experiment(DATASET3, DATASET3.Exp_Aligned)
# Out:
# ...Building Final Interpolator...
# Time taken to load Interpolator: 4.091563940048218
# Loading Experiment from DataFiles_to_Dinesh_Pranav\Data_files\Experiment\26_03_2026_CW_data\Bz_V_Readout_By_2.csv...
#   > Exp Start: -0.1100s
# 0.24181842803955078 was the time taken to load exp data.

# %%
# t_exp, f_bias_axis, exp_matrix = cp.asarray(t_exp), cp.asarray(f_bias_axis), cp.asarray(exp_matrix)
exp_matrix_final_time = exp_matrix[-1,:]
print(exp_matrix.shape, exp_matrix_final_time.shape)
print(np.argmax(exp_matrix_final_time[50:60]), np.max(exp_matrix_final_time[50:60]))
print(f_bias_axis[50:60][np.argmax(exp_matrix_final_time[50:60])])
cpt_peak_loc = f_bias_axis[50:60][np.argmax(exp_matrix_final_time[50:60])]
print(np.where(f_bias_axis == cpt_peak_loc)[0][0])
plt.plot(f_bias_axis[50:60], exp_matrix_final_time[50:60], label="Experiment Final Time", color="red")
plt.show(0)
plt.plot(f_bias_axis, exp_matrix_final_time, label="Experiment Final Time", color="red")
# Out:
# (4376, 111) (111,)
# 4 0.9607250475267908
# -0.0446259231987862
# 54

# %% [markdown]
# So, now we simply add cpt_peak_loc, to recentre the axis to zero or we set Bz_unk = cpt_peak_loc

# %%
final_time = t_exp[-1]

# %%
sim_matrix_fixed_time = get_predictions_batch(sim_spline, final_time, f_sim, by_sim)
print(sim_matrix_fixed_time.shape)
print(by_sim[0])
# Out:
# 0.49269986152648926 was the time taken to compute the Interpolated Values.| (91, 51)
# 0.0

# %%
plt.plot(f_sim.get(), sim_matrix_fixed_time[:, 0].get())

# %% [markdown]
# Now construct a function for any given y value and any given x value interpolator; use perhaps some nice cubic spline interpolator

# %%
def f_y_interpolator(t_fixed, bz_query, bz_fixed, by):
    by = cp.asarray(by)
    t_fixed = cp.asarray(t_fixed)
    bz_query = cp.asarray(bz_query)
    bz_fixed = cp.asarray(bz_fixed)
    bz_query = bz_query + bz_fixed
    sim_matrix_fixed_time = get_predictions_batch(sim_spline, t_fixed, bz_query, by)
    print(sim_matrix_fixed_time.shape)
    if by.shape == ():
        return np.squeeze(sim_matrix_fixed_time.get())
    return sim_matrix_fixed_time.get()

# %% [markdown]
# Then construct a simple loss function for the final time slice

# %%
t_fixed = final_time
bz_query = f_bias_axis
by = np.linspace(0, 0.5, 100)

interpolated_values = f_y_interpolator(t_fixed, bz_query, -1*cpt_peak_loc, by)
print(exp_matrix_final_time.shape, interpolated_values.shape)

loss = np.sum((exp_matrix_final_time[:, None] - interpolated_values)**2, axis = 0)

print(by[np.argmin(loss)], np.min(loss))

plt.plot(by,loss, label="Loss vs By", color="green")
plt.legend()
plt.xlabel("By (MHz)")
plt.ylabel("Loss")
plt.title("Loss vs By for fixed time and varying By")
plt.show()
# Out:
# 0.0018537044525146484 was the time taken to compute the Interpolated Values.| (111, 100)
# (111,) (111, 100)
# 0.2878787878787879 1.580062041731177

# %% [markdown]
# Now, lets move onto the curve fit for B_y

# %%
t_val = final_time              
bz_ambient_val = -1 * cpt_peak_loc       

xdata_bz_bias = f_bias_axis  
ydata_transmission = exp_matrix_final_time 

fit_wrapper = lambda x, p_by: f_y_interpolator(t_val, x, bz_ambient_val, p_by)

initial_guess = [0.1] 

lower_bounds = [0.0]
upper_bounds = [1.0]

popt, pcov = curve_fit(
    f=fit_wrapper, 
    xdata=xdata_bz_bias, 
    ydata=ydata_transmission, 
    p0=initial_guess, 
    bounds=(lower_bounds, upper_bounds),
    diff_step = 1e-3,
    x_scale = 'jac',
    ftol = 1e-10,
    xtol = 1e-10,
    gtol = 1e-10
)

by_estimate = popt[0]
by_variance = pcov[0, 0]
by_standard_error = np.sqrt(by_variance)

print(f"Estimated By: {by_estimate:.5f} +/- {by_standard_error:.5f}")
# Out:
# 0.001573324203491211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012011528015136719 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011527538299560547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014154911041259766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011508464813232422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010921955108642578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010766983032226562 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010700225830078125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010755062103271484 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010695457458496094 was the time taken to compute the Interpolated Values.| (111,)
# 0.001096487045288086 was the time taken to compute the Interpolated Values.| (111,)
# 0.00104522705078125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010645389556884766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010848045349121094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010747909545898438 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010695457458496094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010714530944824219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010552406311035156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010540485382080078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010633468627929688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010628700256347656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011224746704101562 was the time taken to compute the Interpolated Values.| (111,)
# 0.001188039779663086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010695457458496094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010623931884765625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010635852813720703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010647773742675781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010526180267333984 was the time taken to compute the Interpolated Values.| (111,)
# 0.001142740249633789 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010826587677001953 was the time taken to compute the Interpolated Values.| (111,)
# Estimated By: 0.28745 +/- 0.00750

# %% [markdown]
# Now construct a function for a fixed y value, independent parameter as bias, and Bzunk as being the parameter to be estimated

# %%
def f_z_interpolator(t_fixed, bz_query, bz, by_fixed):
    by_fixed = cp.asarray(by_fixed)
    t_fixed = cp.asarray(t_fixed)
    bz_query = cp.asarray(bz_query)
    bz = cp.asarray(bz)
    if bz.shape == ():
        bz_query = bz_query + bz
    else:
        bz_query = bz_query[:, None] + bz[None, :]
    sim_matrix_fixed_time = get_predictions_batch(sim_spline, t_fixed, bz_query, by_fixed, mode = 'Longitudinal Likelihood Frequentist')
    print(sim_matrix_fixed_time.shape)
    if bz.shape == ():
        return np.squeeze(sim_matrix_fixed_time.get())
    return sim_matrix_fixed_time.get()

# %%
t_fixed = final_time
bz_query = f_bias_axis
by_fixed = by_estimate

bz = cp.linspace(-1, 1, 1000)

interpolated_values_z = f_z_interpolator(t_fixed, bz_query, bz, by_fixed)
print(exp_matrix_final_time.shape, interpolated_values_z.shape)

loss_z = np.sum((exp_matrix_final_time[:, None] - interpolated_values_z)**2, axis = 0)

print(bz[np.argmin(loss_z)], np.min(loss_z))

plt.plot(bz.get(), loss_z, label="Loss vs Bz", color="purple")
plt.legend()
plt.xlabel("Bz (MHz)")
plt.ylabel("Loss")
plt.title("Loss vs Bz for fixed time and varying Bz")
plt.show()
# Out:
# 0.0019304752349853516 was the time taken to compute the Interpolated Values.| (111, 1000)
# (111,) (111, 1000)
# 0.04304304304304303 1.580012159848391

# %%
t_val = final_time              
by_ambient_val = by_estimate     

xdata_bz_bias = f_bias_axis  
ydata_transmission = exp_matrix_final_time 

fit_wrapper = lambda x, p_bz: f_z_interpolator(t_val, x, p_bz, by_ambient_val)

initial_guess = [0.1] 

lower_bounds = [-1.0]
upper_bounds = [1.0]

popt, pcov = curve_fit(
    f=fit_wrapper, 
    xdata=xdata_bz_bias, 
    ydata=ydata_transmission, 
    p0=initial_guess, 
    bounds=(lower_bounds, upper_bounds),
    diff_step = 1e-3,
    x_scale = 'jac',
    ftol = 1e-10,
    xtol = 1e-10,
    gtol = 1e-10
)

bz_estimate = popt[0]
bz_variance = pcov[0, 0]
bz_standard_error = np.sqrt(bz_variance)

print(f"Estimated Bz: {bz_estimate:.5f} +/- {bz_standard_error:.5f}")
# Out:
# 0.001463174819946289 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011179447174072266 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010960102081298828 was the time taken to compute the Interpolated Values.| (111,)
# 0.001081705093383789 was the time taken to compute the Interpolated Values.| (111,)
# 0.001092672348022461 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010836124420166016 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010807514190673828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010745525360107422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010707378387451172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010714530944824219 was the time taken to compute the Interpolated Values.| (111,)
# 0.001255035400390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.001088857650756836 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010981559753417969 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011696815490722656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010745525360107422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010645389556884766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012655258178710938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011296272277832031 was the time taken to compute the Interpolated Values.| (111,)
# 0.0016808509826660156 was the time taken to compute the Interpolated Values.| (111,)
# 0.001096963882446289 was the time taken to compute the Interpolated Values.| (111,)
# 0.00115203857421875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011096000671386719 was the time taken to compute the Interpolated Values.| (111,)
# 0.001079559326171875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010809898376464844 was the time taken to compute the Interpolated Values.| (111,)
# 0.001096963882446289 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010809898376464844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010776519775390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013093948364257812 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011012554168701172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011005401611328125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011339187622070312 was the time taken to compute the Interpolated Values.| (111,)
# 0.001111745834350586 was the time taken to compute the Interpolated Values.| (111,)
# 0.001096963882446289 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010895729064941406 was the time taken to compute the Interpolated Values.| (111,)
# Estimated Bz: 0.04434 +/- 0.00957

# %% [markdown]
# Now we should write a code for an alternating estimation procedure. How are we doing this?

# %%
tol = 1e-4
t_val = final_time
By_0 = 1e-4
Bz_0 = 1e-4
curr_est = np.asarray([By_0, Bz_0])
old_est = np.asarray([0, 0])

bz_history = [curr_est[1]]
by_history = [curr_est[0]]

while np.linalg.norm(curr_est - old_est) > tol:
    old_est = curr_est.copy()
    #first y
    bz_ambient_val = curr_est[1]     

    xdata_bz_bias = f_bias_axis  
    ydata_transmission = exp_matrix_final_time 

    fit_wrapper = lambda x, p_by: f_y_interpolator(t_val, x, bz_ambient_val, p_by)

    initial_guess = [0.1] 

    lower_bounds = [0.0]
    upper_bounds = [1.0]

    popt, pcov = curve_fit(
        f=fit_wrapper, 
        xdata=xdata_bz_bias, 
        ydata=ydata_transmission, 
        p0=initial_guess, 
        bounds=(lower_bounds, upper_bounds),
        diff_step = 1e-3,
        x_scale = 'jac',
        ftol = 1e-10,
        xtol = 1e-10,
        gtol = 1e-10
    )

    curr_est[0] = popt[0]
    by_variance = pcov[0, 0]
    by_standard_error = np.sqrt(by_variance)


    #next z
    by_ambient_val = curr_est[0]     

    xdata_bz_bias = f_bias_axis  
    ydata_transmission = exp_matrix_final_time 

    fit_wrapper = lambda x, p_bz: f_z_interpolator(t_val, x, p_bz, by_ambient_val)

    initial_guess = [0.1] 

    lower_bounds = [-1.0]
    upper_bounds = [1.0]

    popt, pcov = curve_fit(
        f=fit_wrapper, 
        xdata=xdata_bz_bias, 
        ydata=ydata_transmission, 
        p0=initial_guess, 
        bounds=(lower_bounds, upper_bounds),
        diff_step = 1e-3,
        x_scale = 'jac',
        ftol = 1e-10,
        xtol = 1e-10,
        gtol = 1e-10
    )

    curr_est[1] = popt[0]
    bz_variance = pcov[0, 0]
    bz_standard_error = np.sqrt(bz_variance)
    bz_history.append(curr_est[1])
    by_history.append(curr_est[0])


print(bz_history[-1])
print(by_history[-1])

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(range(len(by_history)), by_history, label="By Estimate", color="green")
plt.xlabel("Iteration")
plt.ylabel("By (MHz)")
plt.title("By Estimate Convergence")
plt.subplot(1,2,2)
plt.plot(range(len(bz_history)), bz_history, label="Bz Estimate", color="purple")
plt.xlabel("Iteration")
plt.ylabel("Bz (MHz)")  
plt.title("Bz Estimate Convergence")
plt.tight_layout()
plt.savepath = os.path.join(DATASET3.save_path, "By_Bz_Convergence.png")
plt.savefig(plt.savepath)
plt.show()
# Out:
# 0.0018956661224365234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011522769927978516 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011773109436035156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012493133544921875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010783672332763672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011932849884033203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012135505676269531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010979175567626953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010876655578613281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010790824890136719 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011546611785888672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010724067687988281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010609626770019531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010981559753417969 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012485980987548828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011360645294189453 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010793209075927734 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010852813720703125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010743141174316406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010612010955810547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010852813720703125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011188983917236328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010762214660644531 was the time taken to compute the Interpolated Values.| (111,)
# 0.001275777816772461 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005633831024169922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005168914794921875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005705356597900391 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005118846893310547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005323886871337891 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005588531494140625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005724430084228516 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005381107330322266 was the time taken to compute the Interpolated Values.| (111,)
# 0.000568389892578125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005400180816650391 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005800724029541016 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005056858062744141 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005333423614501953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005018711090087891 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045299530029296875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004458427429199219 was the time taken to compute the Interpolated Values.| (111,)
# 0.00047898292541503906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005259513854980469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005021095275878906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004570484161376953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004572868347167969 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005319118499755859 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004725456237792969 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005033016204833984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004730224609375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004391670227050781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004773139953613281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004642009735107422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004563331604003906 was the time taken to compute the Interpolated Values.| (111,)
# 0.00048041343688964844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004742145538330078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004436969757080078 was the time taken to compute the Interpolated Values.| (111,)
# 0.00047898292541503906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005970001220703125 was the time taken to compute the Interpolated Values.| (111,)
# 0.00047850608825683594 was the time taken to compute the Interpolated Values.| (111,)
# 0.00047850608825683594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004723072052001953 was the time taken to compute the Interpolated Values.| (111,)
# 0.00048732757568359375 was the time taken to compute the Interpolated Values.| (111,)
# 0.00043964385986328125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005035400390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.00044274330139160156 was the time taken to compute the Interpolated Values.| (111,)
# 0.00044918060302734375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004439353942871094 was the time taken to compute the Interpolated Values.| (111,)
# 0.00042319297790527344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005805492401123047 was the time taken to compute the Interpolated Values.| (111,)
# 0.00046563148498535156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004754066467285156 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045871734619140625 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045037269592285156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004508495330810547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005013942718505859 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004863739013671875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004355907440185547 was the time taken to compute the Interpolated Values.| (111,)
# 0.00043129920959472656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0008115768432617188 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011646747589111328 was the time taken to compute the Interpolated Values.| (111,)
# 0.001089334487915039 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010678768157958984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011682510375976562 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010673999786376953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012052059173583984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010848045349121094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010662078857421875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011701583862304688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011115074157714844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010695457458496094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010647773742675781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010769367218017578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010809898376464844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011835098266601562 was the time taken to compute the Interpolated Values.| (111,)
# 0.001062631607055664 was the time taken to compute the Interpolated Values.| (111,)
# 0.001056671142578125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010693073272705078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011570453643798828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010554790496826172 was the time taken to compute the Interpolated Values.| (111,)
# 0.00107574462890625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010707378387451172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010755062103271484 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010590553283691406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010564327239990234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010657310485839844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010633468627929688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011093616485595703 was the time taken to compute the Interpolated Values.| (111,)
# 0.00048613548278808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004801750183105469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009551048278808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.00069427490234375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005240440368652344 was the time taken to compute the Interpolated Values.| (111,)
# 0.00046634674072265625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004315376281738281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004775524139404297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004703998565673828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011858940124511719 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011317729949951172 was the time taken to compute the Interpolated Values.| (111,)
# 0.001177072525024414 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011737346649169922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010924339294433594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011146068572998047 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011074542999267578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010704994201660156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010700225830078125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010709762573242188 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011324882507324219 was the time taken to compute the Interpolated Values.| (111,)
# 0.001077413558959961 was the time taken to compute the Interpolated Values.| (111,)
# 0.0017404556274414062 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011196136474609375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010743141174316406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010645389556884766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010628700256347656 was the time taken to compute the Interpolated Values.| (111,)
# 0.00107574462890625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011212825775146484 was the time taken to compute the Interpolated Values.| (111,)
# 0.001226186752319336 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011358261108398438 was the time taken to compute the Interpolated Values.| (111,)
# 0.001298666000366211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011639595031738281 was the time taken to compute the Interpolated Values.| (111,)
# 0.001085042953491211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011162757873535156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011088848114013672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0015590190887451172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011680126190185547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010716915130615234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010738372802734375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013928413391113281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011222362518310547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010986328125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010824203491210938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010800361633300781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010724067687988281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010671615600585938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010769367218017578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010771751403808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.001359701156616211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004601478576660156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004620552062988281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009617805480957031 was the time taken to compute the Interpolated Values.| (111,)
# 0.00093841552734375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009860992431640625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004954338073730469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010972023010253906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011854171752929688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010743141174316406 was the time taken to compute the Interpolated Values.| (111,)
# 0.001081705093383789 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012679100036621094 was the time taken to compute the Interpolated Values.| (111,)
# 0.001130819320678711 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011105537414550781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010764598846435547 was the time taken to compute the Interpolated Values.| (111,)
# 0.001068115234375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011014938354492188 was the time taken to compute the Interpolated Values.| (111,)
# 0.001077413558959961 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010836124420166016 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010581016540527344 was the time taken to compute the Interpolated Values.| (111,)
# 0.001199483871459961 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004909038543701172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004215240478515625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0008919239044189453 was the time taken to compute the Interpolated Values.| (111,)
# 0.000644683837890625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009326934814453125 was the time taken to compute the Interpolated Values.| (111,)
# 0.000545501708984375 was the time taken to compute the Interpolated Values.| (111,)
# 0.000522613525390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010170936584472656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011134147644042969 was the time taken to compute the Interpolated Values.| (111,)
# 0.001069784164428711 was the time taken to compute the Interpolated Values.| (111,)
# 0.001279592514038086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013053417205810547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010862350463867188 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010650157928466797 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011069774627685547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011794567108154297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010843276977539062 was the time taken to compute the Interpolated Values.| (111,)
# 0.001074075698852539 was the time taken to compute the Interpolated Values.| (111,)
# 0.001119375228881836 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010709762573242188 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013818740844726562 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012142658233642578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010747909545898438 was the time taken to compute the Interpolated Values.| (111,)
# 0.001107931137084961 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011019706726074219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011951923370361328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010631084442138672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010607242584228516 was the time taken to compute the Interpolated Values.| (111,)
# 0.001062154769897461 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013022422790527344 was the time taken to compute the Interpolated Values.| (111,)
# 0.001085042953491211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010814666748046875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010941028594970703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010788440704345703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011188983917236328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010607242584228516 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012500286102294922 was the time taken to compute the Interpolated Values.| (111,)
# 0.001079559326171875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012209415435791016 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011582374572753906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010797977447509766 was the time taken to compute the Interpolated Values.| (111,)
# 0.001074075698852539 was the time taken to compute the Interpolated Values.| (111,)
# 0.00103759765625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010547637939453125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010631084442138672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010616779327392578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010612010955810547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010504722595214844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013265609741210938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010724067687988281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010814666748046875 was the time taken to compute the Interpolated Values.| (111,)
# 0.001081705093383789 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010747909545898438 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010616779327392578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010614395141601562 was the time taken to compute the Interpolated Values.| (111,)
# 0.001146554946899414 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010752677917480469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014595985412597656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011119842529296875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010671615600585938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010671615600585938 was the time taken to compute the Interpolated Values.| (111,)
# 0.001068115234375 was the time taken to compute the Interpolated Values.| (111,)
# 0.001064300537109375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010581016540527344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010561943054199219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010671615600585938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011022090911865234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012755393981933594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010731220245361328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010762214660644531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011022090911865234 was the time taken to compute the Interpolated Values.| (111,)
# 0.001062154769897461 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011641979217529297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010635852813720703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012331008911132812 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011136531829833984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014760494232177734 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009362697601318359 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011377334594726562 was the time taken to compute the Interpolated Values.| (111,)
# 0.001074075698852539 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011074542999267578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010638236999511719 was the time taken to compute the Interpolated Values.| (111,)
# 0.001058816909790039 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011591911315917969 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011339187622070312 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012679100036621094 was the time taken to compute the Interpolated Values.| (111,)
# 0.001155853271484375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011043548583984375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010945796966552734 was the time taken to compute the Interpolated Values.| (111,)
# 0.001073598861694336 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011649131774902344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011324882507324219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010640621185302734 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010800361633300781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0015821456909179688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011229515075683594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010890960693359375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010783672332763672 was the time taken to compute the Interpolated Values.| (111,)
# 0.001066446304321289 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011754035949707031 was the time taken to compute the Interpolated Values.| (111,)
# 0.001071929931640625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010616779327392578 was the time taken to compute the Interpolated Values.| (111,)
# 0.001068115234375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014495849609375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011210441589355469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010881423950195312 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010747909545898438 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010607242584228516 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010724067687988281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012888908386230469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010859966278076172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010733604431152344 was the time taken to compute the Interpolated Values.| (111,)
# 0.001071929931640625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0015652179718017578 was the time taken to compute the Interpolated Values.| (111,)
# 0.001130819320678711 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010838508605957031 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012080669403076172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010619163513183594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010645389556884766 was the time taken to compute the Interpolated Values.| (111,)
# 0.001375436782836914 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010902881622314453 was the time taken to compute the Interpolated Values.| (111,)
# 0.0015354156494140625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009632110595703125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005006790161132812 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005252361297607422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005469322204589844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004916191101074219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004916191101074219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010020732879638672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0008761882781982422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004456043243408203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004258155822753906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004563331604003906 was the time taken to compute the Interpolated Values.| (111,)
# 0.00044989585876464844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005147457122802734 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004487037658691406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0008070468902587891 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011172294616699219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010786056518554688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010693073272705078 was the time taken to compute the Interpolated Values.| (111,)
# 0.001074075698852539 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012881755828857422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010631084442138672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011012554168701172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010960102081298828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010690689086914062 was the time taken to compute the Interpolated Values.| (111,)
# 0.001127004623413086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011467933654785156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010991096496582031 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010802745819091797 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010809898376464844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012154579162597656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010993480682373047 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010673999786376953 was the time taken to compute the Interpolated Values.| (111,)
# 0.001363515853881836 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012264251708984375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010864734649658203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010638236999511719 was the time taken to compute the Interpolated Values.| (111,)
# 0.001066446304321289 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011792182922363281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012557506561279297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011212825775146484 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010874271392822266 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012505054473876953 was the time taken to compute the Interpolated Values.| (111,)
# 0.001123666763305664 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011627674102783203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010695457458496094 was the time taken to compute the Interpolated Values.| (111,)
# 0.001065969467163086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010759830474853516 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010716915130615234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010676383972167969 was the time taken to compute the Interpolated Values.| (111,)
# 0.00106048583984375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011959075927734375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011107921600341797 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010809898376464844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014684200286865234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014951229095458984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012981891632080078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014858245849609375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014090538024902344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0020186901092529297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010945796966552734 was the time taken to compute the Interpolated Values.| (111,)
# 0.0016622543334960938 was the time taken to compute the Interpolated Values.| (111,)
# 0.001251220703125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012965202331542969 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012140274047851562 was the time taken to compute the Interpolated Values.| (111,)
# 0.0015995502471923828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014421939849853516 was the time taken to compute the Interpolated Values.| (111,)
# 0.001989126205444336 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013294219970703125 was the time taken to compute the Interpolated Values.| (111,)
# 0.001371145248413086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0017895698547363281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0015485286712646484 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011017322540283203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012764930725097656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004987716674804688 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045108795166015625 was the time taken to compute the Interpolated Values.| (111,)
# 0.001102447509765625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011866092681884766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014789104461669922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011136531829833984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010731220245361328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010838508605957031 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010805130004882812 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010957717895507812 was the time taken to compute the Interpolated Values.| (111,)
# 0.00109100341796875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010790824890136719 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010712146759033203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010790824890136719 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010814666748046875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010707378387451172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010709762573242188 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011227130889892578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012745857238769531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011463165283203125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011031627655029297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010983943939208984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010876655578613281 was the time taken to compute the Interpolated Values.| (111,)
# 0.001071929931640625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010654926300048828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010881423950195312 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010840892791748047 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014793872833251953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011553764343261719 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010848045349121094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010788440704345703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010797977447509766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010797977447509766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010726451873779297 was the time taken to compute the Interpolated Values.| (111,)
# 0.001068115234375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010609626770019531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012822151184082031 was the time taken to compute the Interpolated Values.| (111,)
# 0.001119375228881836 was the time taken to compute the Interpolated Values.| (111,)
# 0.001096487045288086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010750293731689453 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010783672332763672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010793209075927734 was the time taken to compute the Interpolated Values.| (111,)
# 0.001117706298828125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010776519775390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011012554168701172 was the time taken to compute the Interpolated Values.| (111,)
# 0.001210927963256836 was the time taken to compute the Interpolated Values.| (111,)
# 0.001149892807006836 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011065006256103516 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012586116790771484 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011239051818847656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011000633239746094 was the time taken to compute the Interpolated Values.| (111,)
# 0.001089334487915039 was the time taken to compute the Interpolated Values.| (111,)
# 0.001071929931640625 was the time taken to compute the Interpolated Values.| (111,)
# 0.001065969467163086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004992485046386719 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009016990661621094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009696483612060547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009524822235107422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0006797313690185547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004603862762451172 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045228004455566406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004439353942871094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004825592041015625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004925727844238281 was the time taken to compute the Interpolated Values.| (111,)
# 0.00044918060302734375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004856586456298828 was the time taken to compute the Interpolated Values.| (111,)
# 0.00044155120849609375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004782676696777344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004544258117675781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004792213439941406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009760856628417969 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011358261108398438 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010862350463867188 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010712146759033203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011343955993652344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010960102081298828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010726451873779297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010905265808105469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010530948638916016 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011186599731445312 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011639595031738281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011401176452636719 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010712146759033203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011034011840820312 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010662078857421875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010559558868408203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010557174682617188 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010647773742675781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010693073272705078 was the time taken to compute the Interpolated Values.| (111,)
# 0.001294851303100586 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010886192321777344 was the time taken to compute the Interpolated Values.| (111,)
# 0.001074075698852539 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010879039764404297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010704994201660156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010559558868408203 was the time taken to compute the Interpolated Values.| (111,)
# 0.001065969467163086 was the time taken to compute the Interpolated Values.| (111,)
# 0.001096963882446289 was the time taken to compute the Interpolated Values.| (111,)
# 0.001066446304321289 was the time taken to compute the Interpolated Values.| (111,)
# 0.001085042953491211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010728836059570312 was the time taken to compute the Interpolated Values.| (111,)
# 0.001054525375366211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010671615600585938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012085437774658203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011889934539794922 was the time taken to compute the Interpolated Values.| (111,)
# 0.00119781494140625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010814666748046875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010690689086914062 was the time taken to compute the Interpolated Values.| (111,)
# 0.001066446304321289 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011172294616699219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011458396911621094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010821819305419922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010826587677001953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010733604431152344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010597705841064453 was the time taken to compute the Interpolated Values.| (111,)
# 0.001100301742553711 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011408329010009766 was the time taken to compute the Interpolated Values.| (111,)
# 0.001237630844116211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011289119720458984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011157989501953125 was the time taken to compute the Interpolated Values.| (111,)
# 0.001065969467163086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010716915130615234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010673999786376953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010521411895751953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010528564453125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010635852813720703 was the time taken to compute the Interpolated Values.| (111,)
# 0.001434326171875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010786056518554688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010807514190673828 was the time taken to compute the Interpolated Values.| (111,)
# 0.001093149185180664 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010986328125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010576248168945312 was the time taken to compute the Interpolated Values.| (111,)
# 0.001123666763305664 was the time taken to compute the Interpolated Values.| (111,)
# 0.001093149185180664 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014557838439941406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010538101196289062 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011138916015625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010676383972167969 was the time taken to compute the Interpolated Values.| (111,)
# 0.001056671142578125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010898113250732422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010685920715332031 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013928413391113281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010750293731689453 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011034011840820312 was the time taken to compute the Interpolated Values.| (111,)
# 0.001337289810180664 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012018680572509766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013599395751953125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011336803436279297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011115074157714844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013213157653808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010929107666015625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011014938354492188 was the time taken to compute the Interpolated Values.| (111,)
# 0.001543283462524414 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004966259002685547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005016326904296875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004811286926269531 was the time taken to compute the Interpolated Values.| (111,)
# 0.00048351287841796875 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045943260192871094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005574226379394531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004329681396484375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005586147308349609 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004627704620361328 was the time taken to compute the Interpolated Values.| (111,)
# 0.00044536590576171875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004420280456542969 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004906654357910156 was the time taken to compute the Interpolated Values.| (111,)
# 0.000476837158203125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004570484161376953 was the time taken to compute the Interpolated Values.| (111,)
# 0.000713348388671875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011103153228759766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011746883392333984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010890960693359375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010771751403808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011026859283447266 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011019706726074219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011470317840576172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012612342834472656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010991096496582031 was the time taken to compute the Interpolated Values.| (111,)
# 0.001287698745727539 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011973381042480469 was the time taken to compute the Interpolated Values.| (111,)
# 0.001140594482421875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010743141174316406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010669231414794922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010802745819091797 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010998249053955078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010807514190673828 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010616779327392578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011377334594726562 was the time taken to compute the Interpolated Values.| (111,)
# 0.0008687973022460938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011379718780517578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010852813720703125 was the time taken to compute the Interpolated Values.| (111,)
# 0.001066446304321289 was the time taken to compute the Interpolated Values.| (111,)
# 0.001180410385131836 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011801719665527344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011830329895019531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010809898376464844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011591911315917969 was the time taken to compute the Interpolated Values.| (111,)
# ...
# 0.0010645389556884766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010616779327392578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010607242584228516 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010077953338623047 was the time taken to compute the Interpolated Values.| (111,)
# 0.00046372413635253906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004515647888183594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004482269287109375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004222393035888672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010023117065429688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0007507801055908203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005033016204833984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005195140838623047 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005309581756591797 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010068416595458984 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013852119445800781 was the time taken to compute the Interpolated Values.| (111,)
# 0.001268148422241211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011067390441894531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010669231414794922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010776519775390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011861324310302734 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010845661163330078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011181831359863281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010900497436523438 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010597705841064453 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010693073272705078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012295246124267578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010957717895507812 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011093616485595703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010628700256347656 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011277198791503906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010623931884765625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012104511260986328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010900497436523438 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010797977447509766 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010771751403808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011529922485351562 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010821819305419922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010704994201660156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010743141174316406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010762214660644531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010726451873779297 was the time taken to compute the Interpolated Values.| (111,)
# 0.001062631607055664 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010554790496826172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010600090026855469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011875629425048828 was the time taken to compute the Interpolated Values.| (111,)
# 0.000499725341796875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004374980926513672 was the time taken to compute the Interpolated Values.| (111,)
# 0.00047087669372558594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004916191101074219 was the time taken to compute the Interpolated Values.| (111,)
# 0.000514984130859375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004763603210449219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004763603210449219 was the time taken to compute the Interpolated Values.| (111,)
# 0.00047659873962402344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004665851593017578 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010693073272705078 was the time taken to compute the Interpolated Values.| (111,)
# 0.001093149185180664 was the time taken to compute the Interpolated Values.| (111,)
# 0.0015294551849365234 was the time taken to compute the Interpolated Values.| (111,)
# 0.00139617919921875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011019706726074219 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011000633239746094 was the time taken to compute the Interpolated Values.| (111,)
# 0.001081228256225586 was the time taken to compute the Interpolated Values.| (111,)
# 0.001064300537109375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010683536529541016 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011844635009765625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011146068572998047 was the time taken to compute the Interpolated Values.| (111,)
# 0.001237630844116211 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013535022735595703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010764598846435547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011093616485595703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010712146759033203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011599063873291016 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011339187622070312 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010845661163330078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010771751403808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.001066446304321289 was the time taken to compute the Interpolated Values.| (111,)
# 0.001470804214477539 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011124610900878906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010771751403808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010559558868408203 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010600090026855469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010652542114257812 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010547637939453125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010533332824707031 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011272430419921875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012583732604980469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010745525360107422 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010747909545898438 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010762214660644531 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010612010955810547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011284351348876953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010650157928466797 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010652542114257812 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010647773742675781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010535717010498047 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005462169647216797 was the time taken to compute the Interpolated Values.| (111,)
# 0.000461578369140625 was the time taken to compute the Interpolated Values.| (111,)
# 0.00046563148498535156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005133152008056641 was the time taken to compute the Interpolated Values.| (111,)
# 0.001119852066040039 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010776519775390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010704994201660156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011446475982666016 was the time taken to compute the Interpolated Values.| (111,)
# 0.001190185546875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012445449829101562 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014111995697021484 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011146068572998047 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011124610900878906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010685920715332031 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011641979217529297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010669231414794922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011010169982910156 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011222362518310547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010724067687988281 was the time taken to compute the Interpolated Values.| (111,)
# 0.0016200542449951172 was the time taken to compute the Interpolated Values.| (111,)
# 0.001130819320678711 was the time taken to compute the Interpolated Values.| (111,)
# 0.001112222671508789 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010800361633300781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010554790496826172 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010683536529541016 was the time taken to compute the Interpolated Values.| (111,)
# 0.001306295394897461 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010883808135986328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011055469512939453 was the time taken to compute the Interpolated Values.| (111,)
# 0.001119852066040039 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010802745819091797 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010743141174316406 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010874271392822266 was the time taken to compute the Interpolated Values.| (111,)
# 0.001138925552368164 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010590553283691406 was the time taken to compute the Interpolated Values.| (111,)
# 0.001050710678100586 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010631084442138672 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010612010955810547 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010631084442138672 was the time taken to compute the Interpolated Values.| (111,)
# 0.00046539306640625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0009706020355224609 was the time taken to compute the Interpolated Values.| (111,)
# 0.00051116943359375 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045752525329589844 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004668235778808594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004634857177734375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004534721374511719 was the time taken to compute the Interpolated Values.| (111,)
# 0.00046825408935546875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004730224609375 was the time taken to compute the Interpolated Values.| (111,)
# 0.000492095947265625 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045299530029296875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005259513854980469 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005035400390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.00045013427734375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005140304565429688 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005040168762207031 was the time taken to compute the Interpolated Values.| (111,)
# 0.00042557716369628906 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012688636779785156 was the time taken to compute the Interpolated Values.| (111,)
# 0.001096487045288086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011157989501953125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011036396026611328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010592937469482422 was the time taken to compute the Interpolated Values.| (111,)
# 0.001058816909790039 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010671615600585938 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011491775512695312 was the time taken to compute the Interpolated Values.| (111,)
# 0.001049041748046875 was the time taken to compute the Interpolated Values.| (111,)
# 0.001430511474609375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012447834014892578 was the time taken to compute the Interpolated Values.| (111,)
# 0.001089334487915039 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012547969818115234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010979175567626953 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010848045349121094 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010666847229003906 was the time taken to compute the Interpolated Values.| (111,)
# 0.00106048583984375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010564327239990234 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011184215545654297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010547637939453125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010704994201660156 was the time taken to compute the Interpolated Values.| (111,)
# 0.001071929931640625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011777877807617188 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011909008026123047 was the time taken to compute the Interpolated Values.| (111,)
# 0.001073598861694336 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011856555938720703 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011036396026611328 was the time taken to compute the Interpolated Values.| (111,)
# 0.0014696121215820312 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010833740234375 was the time taken to compute the Interpolated Values.| (111,)
# 0.001065969467163086 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010595321655273438 was the time taken to compute the Interpolated Values.| (111,)
# 0.001074075698852539 was the time taken to compute the Interpolated Values.| (111,)
# 0.001062154769897461 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010766983032226562 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010540485382080078 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010576248168945312 was the time taken to compute the Interpolated Values.| (111,)
# 0.0016009807586669922 was the time taken to compute the Interpolated Values.| (111,)
# 0.001251220703125 was the time taken to compute the Interpolated Values.| (111,)
# 0.0013010501861572266 was the time taken to compute the Interpolated Values.| (111,)
# 0.04410928137389392
# 0.2870909419553408

# %%
# Assuming t_val is your frozen time slice
def fit_joint_wrapper(xdata_bz_bias, bz_guess, by_guess):
    by_guess = cp.asarray(by_guess)
    t_fixed = cp.asarray(final_time)
    bz_query = cp.asarray(xdata_bz_bias)
    bz_guess = cp.asarray(bz_guess)
    if bz_guess.shape == ():
        bz_query = bz_query + bz_guess
    else:
        bz_query = bz_query[:, None] + bz_guess[None, :]
    sim_matrix_fixed_time = get_predictions_batch(sim_spline, t_fixed, bz_query, by_guess, mode = 'Longitdinal Likelihood Frequentist')
    print(sim_matrix_fixed_time.shape)
    if by_guess.shape == ():
        return np.squeeze(sim_matrix_fixed_time.get())
    return sim_matrix_fixed_time.get()

# %%
# Converged values from your ALS loop
p0_joint = [bz_history[-1], by_history[-1]] 

# Set bounds to encompass your simulation grid limits
bounds_joint = (
    [-1.0, 0], # Lower bounds for [Bz, By]
    [1.0, 0.5]  # Upper bounds for [Bz, By]
)

popt_joint, pcov_joint = curve_fit(
    f=fit_joint_wrapper,
    xdata=xdata_bz_bias,
    ydata=ydata_transmission,
    p0=p0_joint,
    bounds=bounds_joint,
    diff_step=1e-3,      # Crucial for grid interpolators
    x_scale='jac',       # Handles scale differences between Bz and By
    method='trf'
)

print(popt_joint)
print(pcov_joint)
# Out:
# 0.001598358154296875 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011410713195800781 was the time taken to compute the Interpolated Values.| (111,)
# 0.0010747909545898438 was the time taken to compute the Interpolated Values.| (111,)
# 0.0005035400390625 was the time taken to compute the Interpolated Values.| (111,)
# 0.0006344318389892578 was the time taken to compute the Interpolated Values.| (111,)
# 0.00043845176696777344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0004956722259521484 was the time taken to compute the Interpolated Values.| (111,)
# 0.00047087669372558594 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011610984802246094 was the time taken to compute the Interpolated Values.| (111,)
# 0.001186370849609375 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012958049774169922 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011794567108154297 was the time taken to compute the Interpolated Values.| (111,)
# 0.0012061595916748047 was the time taken to compute the Interpolated Values.| (111,)
# 0.0015006065368652344 was the time taken to compute the Interpolated Values.| (111,)
# 0.0011334419250488281 was the time taken to compute the Interpolated Values.| (111,)
# [0.04410928 0.28709094]
# [[9.65525175e-05 2.29478126e-06]
#  [2.29478126e-06 5.68799798e-05]]

# %%
print(pcov_joint[0,1]/(np.sqrt(pcov_joint[0,0]) * np.sqrt(pcov_joint[1,1])))
# Out:
# 0.03096561972045347

# %% [markdown]
# We are going to see if the transient data can resolve the field components effectively

# %%
i  = 3
j = 8
sigma_noise = 0.4
curr_time = 15.0 + j
prior = 1.0
directory = f"D:\\Pranav_and_Dinesh\\Dinesh\\Results\\Dataset_10\\03_June\\Prior_Test_{prior}\\Linear_Interpolation\\Est_First_Z_False\\Gaussian_Likelihood\\Sigma_{sigma_noise}\\Test_{j//2}_Dataset_10_By_{i}_from_{curr_time}_microseconds_Randomised_Start_Time_Sigma_noise_{sigma_noise}"
result_longitudinal_list = sorted([
    os.path.join(directory, f) for f in os.listdir(directory) if (f.startswith(f"longitudinal_estimation_results_Dataset_10_Starting with{curr_time} us_T Step 0.2 us_plus_0.0_initial estimate_03_06_2026_") or f.startswith(f"longitudinal_estimation_results_Dataset_10_Starting with{curr_time} us_T Step 0.2 us_plus_0.0_initial estimate_25_05_2026_") or f.startswith(f"longitudinal_estimation_results_Dataset_10_Starting with{curr_time} us_T Step 0.2 us_plus_0.0_initial estimate_26_05_2026_") or f.startswith(f"longitudinal_estimation_results_Dataset_10_Starting with{curr_time} us_T Step 0.2 us_plus_0.0_initial estimate_27_05_2026_")) and f.endswith(r".npz")
], key=lambda x: float(x.split(r"_06_2026_")[1].split(r".npz")[0]))
result_transverse_list = sorted([
    os.path.join(directory, f) for f in os.listdir(directory) if (f.startswith(f"transverse_field_estimation_results_Dataset_10_Starting with{curr_time} us_T Step 0.2 us_plus_0.0_initial estimate_03_06_2026_") or f.startswith(f"transverse_field_estimation_results_Dataset_10_Starting with{curr_time} us_T Step 0.2 us_plus_0.0_initial estimate_25_05_2026_") or f.startswith(f"transverse_field_estimation_results_Dataset_10_Starting with{curr_time} us_T Step 0.2 us_plus_0.0_initial estimate_26_05_2026_") or f.startswith(f"transverse_field_estimation_results_Dataset_10_Starting with{curr_time} us_T Step 0.2 us_plus_0.0_initial estimate_27_05_2026_")) and f.endswith(r".npz")
], key=lambda x: float(x.split(r"_06_2026_")[1].split(r".npz")[0]))

# print(len(result_longitudinal_list))

longitudinal_estimation_results = [np.load(f, allow_pickle=True) for f in result_longitudinal_list]
transverse_field_estimation_results = [np.load(f, allow_pickle=True) for f in result_transverse_list]


time = transverse_field_estimation_results[8]["time"]
bias = transverse_field_estimation_results[8]["bias"]
time_1 = longitudinal_estimation_results[8]["time"]
bias_1 = longitudinal_estimation_results[8]["bias"]
print(len(time), len(bias))
print(len(time_1), len(bias_1))
# Out:
# 251 251
# 240 240

# %% [markdown]
# We are going to do a NLLS with the time stamp.

# %%
t_exp, f_bias_axis, exp_matrix = cp.asarray(t_exp), cp.asarray(f_bias_axis), cp.asarray(exp_matrix)

# %%
MAX_TIME = 70.0
curr_time = time[0]
exp_data_to_compare = cp.array([])

t_sim_query = []
i = 0
while curr_time <= MAX_TIME:
    t_start = curr_time
    t_end = curr_time + 0.2
    curr_time += 0.2

    idx_start = cp.searchsorted(t_exp, cp.asarray(t_start))
    idx_end = cp.searchsorted(t_exp, cp.asarray(t_end))
    bias_idx = cp.searchsorted(f_bias_axis, cp.asarray(bias[i]))
    exp_data_to_compare = cp.concatenate((exp_data_to_compare, exp_matrix[idx_start:idx_end, bias_idx]), axis=0)
    t_sim_query.append(t_exp[idx_start:idx_end].get())

    i+=1

MAX_TIME = 70.0
curr_time = time_1[0]
i = 0
while curr_time <= MAX_TIME:
    t_start = curr_time
    t_end = curr_time + 0.2
    curr_time += 0.2

    idx_start = cp.searchsorted(t_exp, cp.asarray(t_start))
    idx_end = cp.searchsorted(t_exp, cp.asarray(t_end))
    bias_idx = cp.searchsorted(f_bias_axis, cp.asarray(bias_1[i]))
    exp_data_to_compare = cp.concatenate((exp_data_to_compare, exp_matrix[idx_start:idx_end, bias_idx]), axis=0)
    t_sim_query.append(t_exp[idx_start:idx_end].get())

    i+=1

# %% [markdown]
# 2D Loss Landscape

# %%
def fitting_func_demo(bz_guess, by_guess):
    by_guess = cp.asarray(by_guess)
    bz_guess = cp.asarray(bz_guess)

    sim_matrix_to_compare = np.empty((0, bz_guess.shape[0], by_guess.shape[0]))
    curr_time = time[0]
    i=0
    while curr_time <= MAX_TIME:
        curr_bias = bias[i]
        bz_query = curr_bias + bz_guess
        i+=1

        t_start = curr_time
        t_end = curr_time + 0.2
        curr_time += 0.2

        idx_start = cp.searchsorted(t_exp, cp.asarray(t_start))
        idx_end = cp.searchsorted(t_exp, cp.asarray(t_end))

        t_query = t_exp[idx_start:idx_end]
        sim_matrix_time_series = get_predictions_batch(sim_spline, t_query, bz_query, by_guess, mode = 'Time Series Frequentist')
        sim_matrix_time_series = sim_matrix_time_series.get()
        # print(sim_matrix_time_series.shape)
        sim_matrix_to_compare = np.concatenate((sim_matrix_to_compare, sim_matrix_time_series), axis=0)

    
    curr_time = time_1[0]
    i=0
    while curr_time <= MAX_TIME:
        curr_bias = bias_1[i]
        bz_query = curr_bias + bz_guess
        i+=1

        t_start = curr_time
        t_end = curr_time + 0.2
        curr_time += 0.2

        idx_start = cp.searchsorted(t_exp, cp.asarray(t_start))
        idx_end = cp.searchsorted(t_exp, cp.asarray(t_end))

        t_query = t_exp[idx_start:idx_end]
        sim_matrix_time_series = get_predictions_batch(sim_spline, t_query, bz_query, by_guess, mode = 'Time Series Frequentist')
        sim_matrix_time_series = sim_matrix_time_series.get()
        # print(sim_matrix_time_series.shape)
        sim_matrix_to_compare = np.concatenate((sim_matrix_to_compare, sim_matrix_time_series), axis=0)
    
    
    return sim_matrix_to_compare

# %%
bz = cp.linspace(-1, 1, 200)
by = cp.linspace(0, 0.5, 200)

interpolated_values_demo = fitting_func_demo(bz, by)

print(interpolated_values_demo.shape, exp_data_to_compare.shape)
# Out:
# (6110, 200, 200) (6110,)

# %%
base_cmap = plt.get_cmap('inferno')

# Sample the colormap from 0.2 to 1.0, explicitly skipping the darkest 20%
color_array = base_cmap(np.linspace(0.2, 1.0, 256))

# Create the new, brighter colormap
custom_inferno = mcolors.LinearSegmentedColormap.from_list('inferno_bright', color_array)

# %%
loss_demo = np.sum((exp_data_to_compare.get()[:, None, None] - interpolated_values_demo)**2, axis=0)

#to get coordinate of minimum loss
def scale_ticks(x, pos):
    return f"{int(x / 100)}"

min_loss_idx = np.unravel_index(np.argmin(loss_demo), loss_demo.shape)
print("Minimum Loss at Bz =", bz[min_loss_idx[0]].get(), "MHz, By =", by[min_loss_idx[1]].get(), "MHz with Loss =", loss_demo[min_loss_idx])
fig, ax = plt.subplots(figsize=(8, 6))
norm = mcolors.PowerNorm(gamma=1, vmin=loss_demo.min(), vmax=loss_demo.max())
im = ax.pcolormesh(bz.get() * 100 / 0.7, by.get() * 100 / 0.7, loss_demo.T, shading='gouraud', cmap=custom_inferno, norm = norm)
ax.scatter(bz[min_loss_idx[0]].get() * 100 / 0.7, by[min_loss_idx[1]].get() * 100 / 0.7, color='yellow', marker = "x", label='Minimum Loss Point')

ax.set_xlabel('$B_z$ ($\mathrm{\mu T}$)')
ax.set_ylabel('$B_y$ ($\mathrm{\mu T}$)')
ax.tick_params(axis='both', which='both', top=True, right=True, direction='in', length=6)#, width=1.5)
for spine in ax.spines.values():
    spine.set_linewidth(1.2)
    spine.set_edgecolor('black')
cbar = plt.colorbar(im, label='Loss', ax=ax)
cbar.outline.set_linewidth(1.2)
cbar.outline.set_edgecolor('black')
cbar.ax.tick_params(direction='in', length=6)#, width=1.5)
# 2. Apply this formatter to the colorbar's y-axis
cbar.ax.yaxis.set_major_formatter(ticker.FuncFormatter(scale_ticks))

# 3. Add the scientific multiplier exactly at the top of the colorbar
cbar.ax.set_title(r'$\times \, 10^2$', pad=10, fontsize=15)
plt.savefig("Results\\Plotting\\Frequentist_Loss_Landscape\\Loss_Landscape_by_2_new.png", format = "png", dpi = 1200)
plt.tight_layout()
plt.show()
# plt.title("Loss Landscape Across Adaptive Trajectory")
# pad_and_save(loss_demo.T, filename = "Results\\Plotting\\Frequentist_Loss_Landscape\\loss_matrix.csv")
# pad_and_save([bz.get()* 100 / 0.7], filename = "Results\\Plotting\\Frequentist_Loss_Landscape\\bz_array.csv")
# pad_and_save([by.get()* 100 / 0.7], filename = "Results\\Plotting\\Frequentist_Loss_Landscape\\by_array.csv")
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# <>:14: SyntaxWarning: invalid escape sequence '\m'
# <>:15: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Dinesh\AppData\Local\Temp\ipykernel_17896\3489746219.py:14: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_xlabel('$B_z$ ($\mathrm{\mu T}$)')
# C:\Users\Dinesh\AppData\Local\Temp\ipykernel_17896\3489746219.py:15: SyntaxWarning: invalid escape sequence '\m'
#   ax.set_ylabel('$B_y$ ($\mathrm{\mu T}$)')
# Minimum Loss at Bz = 0.03517587939698494 MHz, By = 0.22613065326633167 MHz with Loss = 203.7405461517475

# %% [markdown]
# 2D NLLS

# %%
def fitting_func(xData,bz_guess, by_guess):
    by_guess = cp.asarray(by_guess)
    bz_guess = cp.asarray(bz_guess)

    sim_matrix_to_compare = np.array([])
    curr_time = time[0]
    i=0
    while curr_time <= MAX_TIME:
        curr_bias = bias[i]
        bz_query = curr_bias + bz_guess
        i+=1

        t_start = curr_time
        t_end = curr_time + 0.2
        curr_time += 0.2

        idx_start = cp.searchsorted(t_exp, cp.asarray(t_start))
        idx_end = cp.searchsorted(t_exp, cp.asarray(t_end))

        t_query = t_exp[idx_start:idx_end]
        sim_matrix_time_series = get_predictions_batch(sim_spline, t_query, bz_query, by_guess, mode = 'Time Series Frequentist')
        sim_matrix_time_series = sim_matrix_time_series.get().flatten()
        # print(sim_matrix_time_series.shape)
        sim_matrix_to_compare = np.concatenate((sim_matrix_to_compare, sim_matrix_time_series), axis=0)
    
    curr_time = time_1[0]
    i=0
    while curr_time <= MAX_TIME:
        curr_bias = bias_1[i]
        bz_query = curr_bias + bz_guess
        i+=1

        t_start = curr_time
        t_end = curr_time + 0.2
        curr_time += 0.2

        idx_start = cp.searchsorted(t_exp, cp.asarray(t_start))
        idx_end = cp.searchsorted(t_exp, cp.asarray(t_end))

        t_query = t_exp[idx_start:idx_end]
        sim_matrix_time_series = get_predictions_batch(sim_spline, t_query, bz_query, by_guess, mode = 'Time Series Frequentist')
        sim_matrix_time_series = sim_matrix_time_series.get().flatten()
        # print(sim_matrix_time_series.shape)
        sim_matrix_to_compare = np.concatenate((sim_matrix_to_compare, sim_matrix_time_series), axis=0)
    
    return sim_matrix_to_compare

# %%
# Converged values from your ALS loop
p0_joint = [0.07, 0.1] 

# Set bounds to encompass your simulation grid limits
bounds_joint = (
    [-1.0, 0], # Lower bounds for [Bz, By]
    [1.0, 0.5]  # Upper bounds for [Bz, By]
)

popt_joint, pcov_joint = curve_fit(
    f=fitting_func,
    xdata=[],
    ydata=exp_data_to_compare.get(),
    p0=p0_joint,
    bounds=bounds_joint,
    diff_step=1e-3,      # Crucial for grid interpolators
    x_scale='jac',       # Handles scale differences between Bz and By
    method='trf'
)

print(popt_joint)
print(pcov_joint)
# Out:
# [0.03843974 0.2897529 ]
# [[9.19105134e-07 6.66769420e-08]
#  [6.66769420e-08 1.55086429e-06]]
